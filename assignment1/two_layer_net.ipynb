# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027204961e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

reg = 0.0
loss, grads = net.loss(X, y, reg=reg)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=reg)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 6.369031e-10
# b2 max relative error: 3.865028e-11
# W1 max relative error: 1.526303e-09
# b1 max relative error: 2.738422e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171490858377

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
    del X_train, y_train
    del X_test, y_test
    print('Clear previously loaded data.')
except:
    pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297603
# iteration 300 / 1000: loss 2.259162
# iteration 400 / 1000: loss 2.203468
# iteration 500 / 1000: loss 2.117619
# iteration 600 / 1000: loss 2.050917
# iteration 700 / 1000: loss 1.987152
# iteration 800 / 1000: loss 2.005458
# iteration 900 / 1000: loss 1.950105
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
from itertools import product

def accuracy(y_true, y_pred):
    return np.mean(y_true == y_pred)

def tune_classifier(X_train, y_train, X_val, y_val, clf_class, param_grid):
    results = {}
    acc_best = -1
    clf_best = None 
    n = len(param_grid)
    for i, params in enumerate(param_grid, 1):
        num_iters, batch_size, lr, reg, hidden_size = params
        print(f"""iteration: {i} / {n}, num_iters: {num_iters}, batch_size: {batch_size}, learning_rate: {lr}, reg: {reg}, hidden_size: {hidden_size}""")
        clf = clf_class
        clf.hidden_size = hidden_size
        clf.train(X_train, y_train, X_val, y_val, learning_rate=lr, reg=reg, num_iters=num_iters, batch_size=batch_size)
        y_pred_train = clf.predict(X_train)
        y_pred_val = clf.predict(X_val)
        acc_train = accuracy(y_train, y_pred_train)
        acc_val = accuracy(y_val, y_pred_val)
        print(f'acc_train: {acc_train}, acc_val: {acc_val}')
        results[params] = acc_train, acc_val
        if acc_val > acc_best:
            acc_best = acc_val
            clf_best = clf

    for lr, reg in sorted(results):
        train_accuracy, val_accuracy = results[(lr, reg)]
        print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                    lr, reg, train_accuracy, val_accuracy))

    print('best validation accuracy achieved during cross-validation: %f' % acc_best)
    
    return clf_best, results

# %%
num_iters = [500, 1000, 3000]
batch_sizes = [100, 200, 500, 1000]
learning_rates = [1e-4, 1e-6, 1e-8]
regularization_strengths = [0, 0.5, 1, 10]
hidden_sizes = [10, 50, 100, 500]
param_grid = list(product(num_iters, batch_sizes, learning_rates, regularization_strengths, hidden_sizes))
net_base = TwoLayerNet(input_size=input_size, output_size=num_classes)
net_best, results = tune_classifier(X_train, y_train, X_val, y_val, net_base, param_grid)
# Out:
# iteration: 1 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.19083673469387755, acc_val: 0.201
# iteration: 2 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.2696530612244898, acc_val: 0.274
# iteration: 3 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.3137755102040816, acc_val: 0.315
# iteration: 4 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.34581632653061223, acc_val: 0.353
# iteration: 5 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.360734693877551, acc_val: 0.371
# iteration: 6 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.37483673469387757, acc_val: 0.383
# iteration: 7 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.3833469387755102, acc_val: 0.388
# iteration: 8 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.39118367346938776, acc_val: 0.382
# iteration: 9 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.3929795918367347, acc_val: 0.387
# iteration: 10 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.398, acc_val: 0.393
# iteration: 11 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.40314285714285714, acc_val: 0.402
# iteration: 12 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.4056734693877551, acc_val: 0.408
# iteration: 13 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.3897551020408163, acc_val: 0.381
# iteration: 14 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.38212244897959186, acc_val: 0.374
# iteration: 15 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.38004081632653064, acc_val: 0.377
# iteration: 16 / 576, num_iters: 500, batch_size: 100, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.37534693877551023, acc_val: 0.378
# iteration: 17 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.37610204081632653, acc_val: 0.379
# iteration: 18 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.37612244897959185, acc_val: 0.378
# iteration: 19 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.376469387755102, acc_val: 0.378
# iteration: 20 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.37681632653061226, acc_val: 0.379
# iteration: 21 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.3765918367346939, acc_val: 0.377
# iteration: 22 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.3767551020408163, acc_val: 0.377
# iteration: 23 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.3770204081632653, acc_val: 0.375
# iteration: 24 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.3772857142857143, acc_val: 0.374
# iteration: 25 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.3773265306122449, acc_val: 0.373
# iteration: 26 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.3773265306122449, acc_val: 0.372
# iteration: 27 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.37785714285714284, acc_val: 0.372
# iteration: 28 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.3780816326530612, acc_val: 0.373
# iteration: 29 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.378, acc_val: 0.373
# iteration: 30 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.3779387755102041, acc_val: 0.372
# iteration: 31 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.37812244897959185, acc_val: 0.372
# iteration: 32 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.3783877551020408, acc_val: 0.371
# iteration: 33 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 34 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 35 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 0, hidden_size: 100
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 36 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 0, hidden_size: 500
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 37 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 0.5, hidden_size: 10
# acc_train: 0.3783877551020408, acc_val: 0.371
# iteration: 38 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 0.5, hidden_size: 50
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 39 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 0.5, hidden_size: 100
# acc_train: 0.3783877551020408, acc_val: 0.371
# iteration: 40 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 0.5, hidden_size: 500
# acc_train: 0.3783877551020408, acc_val: 0.371
# iteration: 41 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 1, hidden_size: 10
# acc_train: 0.3783877551020408, acc_val: 0.371
# iteration: 42 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 1, hidden_size: 50
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 43 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 1, hidden_size: 100
# acc_train: 0.3783877551020408, acc_val: 0.371
# iteration: 44 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 1, hidden_size: 500
# acc_train: 0.3783877551020408, acc_val: 0.371
# iteration: 45 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 46 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 47 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.3783673469387755, acc_val: 0.371
# iteration: 48 / 576, num_iters: 500, batch_size: 100, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.37840816326530613, acc_val: 0.371
# iteration: 49 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.39208163265306123, acc_val: 0.39
# iteration: 50 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.39877551020408164, acc_val: 0.387
# iteration: 51 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.40318367346938777, acc_val: 0.401
# iteration: 52 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.40714285714285714, acc_val: 0.405
# iteration: 53 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.41053061224489795, acc_val: 0.408
# iteration: 54 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.41285714285714287, acc_val: 0.409
# iteration: 55 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.415734693877551, acc_val: 0.409
# iteration: 56 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.41751020408163264, acc_val: 0.411
# iteration: 57 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.4166530612244898, acc_val: 0.407
# iteration: 58 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.41851020408163264, acc_val: 0.412
# iteration: 59 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.41975510204081634, acc_val: 0.409
# iteration: 60 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.42191836734693877, acc_val: 0.413
# iteration: 61 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.4105918367346939, acc_val: 0.401
# iteration: 62 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.39740816326530615, acc_val: 0.398
# iteration: 63 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.3879591836734694, acc_val: 0.383
# iteration: 64 / 576, num_iters: 500, batch_size: 200, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.38442857142857145, acc_val: 0.388
# iteration: 65 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.3843265306122449, acc_val: 0.389
# iteration: 66 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.3843469387755102, acc_val: 0.388
# iteration: 67 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.3843877551020408, acc_val: 0.387
# iteration: 68 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.38426530612244897, acc_val: 0.387
# iteration: 69 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.38412244897959186, acc_val: 0.387
# iteration: 70 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.3842244897959184, acc_val: 0.386
# iteration: 71 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.38446938775510203, acc_val: 0.386
# iteration: 72 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.3843061224489796, acc_val: 0.385
# iteration: 73 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.38442857142857145, acc_val: 0.384
# iteration: 74 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.3847551020408163, acc_val: 0.384
# iteration: 75 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.385, acc_val: 0.385
# iteration: 76 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.3852040816326531, acc_val: 0.386
# iteration: 77 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.3853265306122449, acc_val: 0.386
# iteration: 78 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.3856734693877551, acc_val: 0.386
# iteration: 79 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.38581632653061226, acc_val: 0.387
# iteration: 80 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.3857551020408163, acc_val: 0.387
# iteration: 81 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.3857551020408163, acc_val: 0.387
# iteration: 82 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.3857551020408163, acc_val: 0.387
# iteration: 83 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 0, hidden_size: 100
# acc_train: 0.3857551020408163, acc_val: 0.387
# iteration: 84 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 0, hidden_size: 500
# acc_train: 0.38577551020408163, acc_val: 0.387
# iteration: 85 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 0.5, hidden_size: 10
# acc_train: 0.38577551020408163, acc_val: 0.387
# iteration: 86 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 0.5, hidden_size: 50
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 87 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 0.5, hidden_size: 100
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 88 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 0.5, hidden_size: 500
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 89 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 1, hidden_size: 10
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 90 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 1, hidden_size: 50
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 91 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 1, hidden_size: 100
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 92 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 1, hidden_size: 500
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 93 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 94 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 95 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.38579591836734695, acc_val: 0.387
# iteration: 96 / 576, num_iters: 500, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.38581632653061226, acc_val: 0.387
# iteration: 97 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.3970204081632653, acc_val: 0.396
# iteration: 98 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.4058979591836735, acc_val: 0.408
# iteration: 99 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.41046938775510206, acc_val: 0.414
# iteration: 100 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.41391836734693876, acc_val: 0.411
# iteration: 101 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.41659183673469385, acc_val: 0.41
# iteration: 102 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.4185714285714286, acc_val: 0.41
# iteration: 103 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.41983673469387756, acc_val: 0.414
# iteration: 104 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.42283673469387756, acc_val: 0.413
# iteration: 105 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.42283673469387756, acc_val: 0.412
# iteration: 106 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.42418367346938773, acc_val: 0.41
# iteration: 107 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.4238571428571429, acc_val: 0.412
# iteration: 108 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.4262448979591837, acc_val: 0.415
# iteration: 109 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.41461224489795917, acc_val: 0.407
# iteration: 110 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.40238775510204083, acc_val: 0.393
# iteration: 111 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.39277551020408163, acc_val: 0.395
# iteration: 112 / 576, num_iters: 500, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.38679591836734695, acc_val: 0.39
# iteration: 113 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.38702040816326533, acc_val: 0.39
# iteration: 114 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.38687755102040816, acc_val: 0.391
# iteration: 115 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.38663265306122446, acc_val: 0.39
# iteration: 116 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.38651020408163267, acc_val: 0.391
# iteration: 117 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.3866530612244898, acc_val: 0.392
# iteration: 118 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.38671428571428573, acc_val: 0.393
# iteration: 119 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.3869591836734694, acc_val: 0.393
# iteration: 120 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.3872040816326531, acc_val: 0.393
# iteration: 121 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.3872857142857143, acc_val: 0.391
# iteration: 122 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.3874489795918367, acc_val: 0.391
# iteration: 123 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.38748979591836735, acc_val: 0.394
# iteration: 124 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.38755102040816325, acc_val: 0.394
# iteration: 125 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.3876122448979592, acc_val: 0.393
# iteration: 126 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.3876734693877551, acc_val: 0.393
# iteration: 127 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.387734693877551, acc_val: 0.393
# iteration: 128 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.38785714285714284, acc_val: 0.394
# iteration: 129 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.38785714285714284, acc_val: 0.394
# iteration: 130 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.38787755102040816, acc_val: 0.394
# iteration: 131 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 100
# acc_train: 0.38787755102040816, acc_val: 0.394
# iteration: 132 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 500
# acc_train: 0.38787755102040816, acc_val: 0.394
# iteration: 133 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 0.5, hidden_size: 10
# acc_train: 0.38787755102040816, acc_val: 0.394
# iteration: 134 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 0.5, hidden_size: 50
# acc_train: 0.38787755102040816, acc_val: 0.394
# iteration: 135 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 0.5, hidden_size: 100
# acc_train: 0.38787755102040816, acc_val: 0.394
# iteration: 136 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 0.5, hidden_size: 500
# acc_train: 0.3878367346938775, acc_val: 0.394
# iteration: 137 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 1, hidden_size: 10
# acc_train: 0.38781632653061227, acc_val: 0.394
# iteration: 138 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 1, hidden_size: 50
# acc_train: 0.38779591836734695, acc_val: 0.394
# iteration: 139 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 1, hidden_size: 100
# acc_train: 0.38781632653061227, acc_val: 0.394
# iteration: 140 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 1, hidden_size: 500
# acc_train: 0.38781632653061227, acc_val: 0.394
# iteration: 141 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.38781632653061227, acc_val: 0.394
# iteration: 142 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.38781632653061227, acc_val: 0.394
# iteration: 143 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.38781632653061227, acc_val: 0.394
# iteration: 144 / 576, num_iters: 500, batch_size: 500, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.38781632653061227, acc_val: 0.394
# iteration: 145 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.4009591836734694, acc_val: 0.4
# iteration: 146 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.4050612244897959, acc_val: 0.405
# iteration: 147 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.41130612244897957, acc_val: 0.412
# iteration: 148 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.41508163265306125, acc_val: 0.413
# iteration: 149 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.4176734693877551, acc_val: 0.413
# iteration: 150 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.4186530612244898, acc_val: 0.417
# iteration: 151 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.42220408163265305, acc_val: 0.416
# iteration: 152 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.42346938775510207, acc_val: 0.414
# iteration: 153 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.42457142857142854, acc_val: 0.415
# iteration: 154 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.42489795918367346, acc_val: 0.414
# iteration: 155 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.42587755102040814, acc_val: 0.409
# iteration: 156 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.4263469387755102, acc_val: 0.41
# iteration: 157 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.4162448979591837, acc_val: 0.412
# iteration: 158 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.4044081632653061, acc_val: 0.404
# iteration: 159 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.3955714285714286, acc_val: 0.394
# iteration: 160 / 576, num_iters: 500, batch_size: 1000, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.3908979591836735, acc_val: 0.394
# iteration: 161 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.390734693877551, acc_val: 0.394
# iteration: 162 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.3907551020408163, acc_val: 0.394
# iteration: 163 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.39071428571428574, acc_val: 0.394
# iteration: 164 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.39077551020408163, acc_val: 0.394
# iteration: 165 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.39083673469387753, acc_val: 0.394
# iteration: 166 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.39077551020408163, acc_val: 0.395
# iteration: 167 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.3908979591836735, acc_val: 0.395
# iteration: 168 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.3911428571428571, acc_val: 0.395
# iteration: 169 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.391, acc_val: 0.395
# iteration: 170 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.3912040816326531, acc_val: 0.396
# iteration: 171 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.3910408163265306, acc_val: 0.396
# iteration: 172 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.3913469387755102, acc_val: 0.396
# iteration: 173 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.39155102040816325, acc_val: 0.396
# iteration: 174 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.3917551020408163, acc_val: 0.395
# iteration: 175 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.3917551020408163, acc_val: 0.395
# iteration: 176 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 177 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 178 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.39183673469387753, acc_val: 0.395
# iteration: 179 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 0, hidden_size: 100
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 180 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 0, hidden_size: 500
# acc_train: 0.39183673469387753, acc_val: 0.395
# iteration: 181 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 0.5, hidden_size: 10
# acc_train: 0.39183673469387753, acc_val: 0.395
# iteration: 182 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 0.5, hidden_size: 50
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 183 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 0.5, hidden_size: 100
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 184 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 0.5, hidden_size: 500
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 185 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 1, hidden_size: 10
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 186 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 1, hidden_size: 50
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 187 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 1, hidden_size: 100
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 188 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 1, hidden_size: 500
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 189 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 190 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 191 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 192 / 576, num_iters: 500, batch_size: 1000, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.39185714285714285, acc_val: 0.395
# iteration: 193 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.407734693877551, acc_val: 0.405
# iteration: 194 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.4165510204081633, acc_val: 0.416
# iteration: 195 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.4229183673469388, acc_val: 0.415
# iteration: 196 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.4252448979591837, acc_val: 0.406
# iteration: 197 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.4276938775510204, acc_val: 0.41
# iteration: 198 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.4333061224489796, acc_val: 0.417
# iteration: 199 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.4310816326530612, acc_val: 0.41
# iteration: 200 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.4360816326530612, acc_val: 0.41
# iteration: 201 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.4352244897959184, acc_val: 0.427
# iteration: 202 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.43351020408163266, acc_val: 0.414
# iteration: 203 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.4357755102040816, acc_val: 0.418
# iteration: 204 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.437, acc_val: 0.416
# iteration: 205 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.40383673469387754, acc_val: 0.4
# iteration: 206 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.38881632653061227, acc_val: 0.39
# iteration: 207 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.3816326530612245, acc_val: 0.391
# iteration: 208 / 576, num_iters: 1000, batch_size: 100, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.37679591836734694, acc_val: 0.384
# iteration: 209 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.37757142857142856, acc_val: 0.384
# iteration: 210 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.3779183673469388, acc_val: 0.383
# iteration: 211 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.3783061224489796, acc_val: 0.381
# iteration: 212 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.3783673469387755, acc_val: 0.38
# iteration: 213 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.37904081632653064, acc_val: 0.383
# iteration: 214 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.37942857142857145, acc_val: 0.381
# iteration: 215 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.3796530612244898, acc_val: 0.382
# iteration: 216 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.38018367346938775, acc_val: 0.382
# iteration: 217 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.3803673469387755, acc_val: 0.384
# iteration: 218 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.3810816326530612, acc_val: 0.386
# iteration: 219 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.38140816326530613, acc_val: 0.387
# iteration: 220 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.3817755102040816, acc_val: 0.387
# iteration: 221 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.3819795918367347, acc_val: 0.389
# iteration: 222 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.3820612244897959, acc_val: 0.389
# iteration: 223 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.3821428571428571, acc_val: 0.391
# iteration: 224 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.38210204081632654, acc_val: 0.39
# iteration: 225 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.38212244897959186, acc_val: 0.39
# iteration: 226 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.38212244897959186, acc_val: 0.391
# iteration: 227 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 0, hidden_size: 100
# acc_train: 0.38212244897959186, acc_val: 0.391
# iteration: 228 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 0, hidden_size: 500
# acc_train: 0.38216326530612243, acc_val: 0.391
# iteration: 229 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 0.5, hidden_size: 10
# acc_train: 0.38216326530612243, acc_val: 0.391
# iteration: 230 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 0.5, hidden_size: 50
# acc_train: 0.3821428571428571, acc_val: 0.391
# iteration: 231 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 0.5, hidden_size: 100
# acc_train: 0.3821428571428571, acc_val: 0.391
# iteration: 232 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 0.5, hidden_size: 500
# acc_train: 0.38218367346938775, acc_val: 0.391
# iteration: 233 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 1, hidden_size: 10
# acc_train: 0.3821428571428571, acc_val: 0.391
# iteration: 234 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 1, hidden_size: 50
# acc_train: 0.38216326530612243, acc_val: 0.391
# iteration: 235 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 1, hidden_size: 100
# acc_train: 0.38216326530612243, acc_val: 0.391
# iteration: 236 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 1, hidden_size: 500
# acc_train: 0.38216326530612243, acc_val: 0.391
# iteration: 237 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.38216326530612243, acc_val: 0.391
# iteration: 238 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.38216326530612243, acc_val: 0.391
# iteration: 239 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.38218367346938775, acc_val: 0.391
# iteration: 240 / 576, num_iters: 1000, batch_size: 100, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.38220408163265307, acc_val: 0.391
# iteration: 241 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.40044897959183673, acc_val: 0.399
# iteration: 242 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.41222448979591836, acc_val: 0.413
# iteration: 243 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.41846938775510206, acc_val: 0.414
# iteration: 244 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.42397959183673467, acc_val: 0.417
# iteration: 245 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.4260408163265306, acc_val: 0.416
# iteration: 246 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.4301020408163265, acc_val: 0.414
# iteration: 247 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.4293877551020408, acc_val: 0.409
# iteration: 248 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.4319387755102041, acc_val: 0.41
# iteration: 249 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.43459183673469387, acc_val: 0.41
# iteration: 250 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.4330816326530612, acc_val: 0.41
# iteration: 251 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.43426530612244896, acc_val: 0.412
# iteration: 252 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.4350612244897959, acc_val: 0.413
# iteration: 253 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.4052857142857143, acc_val: 0.397
# iteration: 254 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.3883265306122449, acc_val: 0.386
# iteration: 255 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.38281632653061226, acc_val: 0.382
# iteration: 256 / 576, num_iters: 1000, batch_size: 200, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.38040816326530613, acc_val: 0.383
# iteration: 257 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.3803877551020408, acc_val: 0.385
# iteration: 258 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.3807142857142857, acc_val: 0.383
# iteration: 259 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.38042857142857145, acc_val: 0.384
# iteration: 260 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.38040816326530613, acc_val: 0.386
# iteration: 261 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.3810408163265306, acc_val: 0.386
# iteration: 262 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.3813265306122449, acc_val: 0.384
# iteration: 263 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.381530612244898, acc_val: 0.384
# iteration: 264 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.38195918367346937, acc_val: 0.385
# iteration: 265 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.38246938775510203, acc_val: 0.386
# iteration: 266 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.3826938775510204, acc_val: 0.386
# iteration: 267 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.38285714285714284, acc_val: 0.386
# iteration: 268 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.38316326530612244, acc_val: 0.388
# iteration: 269 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.38320408163265307, acc_val: 0.39
# iteration: 270 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.3835918367346939, acc_val: 0.389
# iteration: 271 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.38348979591836735, acc_val: 0.389
# iteration: 272 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.38393877551020406, acc_val: 0.388
# iteration: 273 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.38393877551020406, acc_val: 0.388
# iteration: 274 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.38387755102040816, acc_val: 0.388
# iteration: 275 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 0, hidden_size: 100
# acc_train: 0.38387755102040816, acc_val: 0.388
# iteration: 276 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 0, hidden_size: 500
# acc_train: 0.38385714285714284, acc_val: 0.388
# iteration: 277 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 0.5, hidden_size: 10
# acc_train: 0.38381632653061226, acc_val: 0.388
# iteration: 278 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 0.5, hidden_size: 50
# acc_train: 0.38385714285714284, acc_val: 0.388
# iteration: 279 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 0.5, hidden_size: 100
# acc_train: 0.38381632653061226, acc_val: 0.388
# iteration: 280 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 0.5, hidden_size: 500
# acc_train: 0.3838367346938775, acc_val: 0.388
# iteration: 281 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 1, hidden_size: 10
# acc_train: 0.38381632653061226, acc_val: 0.388
# iteration: 282 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 1, hidden_size: 50
# acc_train: 0.3838367346938775, acc_val: 0.388
# iteration: 283 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 1, hidden_size: 100
# acc_train: 0.38379591836734694, acc_val: 0.388
# iteration: 284 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 1, hidden_size: 500
# acc_train: 0.38381632653061226, acc_val: 0.388
# iteration: 285 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.3837755102040816, acc_val: 0.388
# iteration: 286 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.38379591836734694, acc_val: 0.388
# iteration: 287 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.3838367346938775, acc_val: 0.388
# iteration: 288 / 576, num_iters: 1000, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.38381632653061226, acc_val: 0.389
# iteration: 289 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.4028163265306122, acc_val: 0.403
# iteration: 290 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.4106734693877551, acc_val: 0.413
# iteration: 291 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.418265306122449, acc_val: 0.41
# iteration: 292 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.42248979591836733, acc_val: 0.413
# iteration: 293 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.42528571428571427, acc_val: 0.406
# iteration: 294 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.428, acc_val: 0.41
# iteration: 295 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.4302244897959184, acc_val: 0.412
# iteration: 296 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.4327142857142857, acc_val: 0.413
# iteration: 297 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.4326122448979592, acc_val: 0.407
# iteration: 298 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.43459183673469387, acc_val: 0.416
# iteration: 299 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.4330204081632653, acc_val: 0.413
# iteration: 300 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.4347142857142857, acc_val: 0.408
# iteration: 301 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.40879591836734697, acc_val: 0.401
# iteration: 302 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.3923469387755102, acc_val: 0.387
# iteration: 303 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.38593877551020406, acc_val: 0.383
# iteration: 304 / 576, num_iters: 1000, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.3822857142857143, acc_val: 0.387
# iteration: 305 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.3824489795918367, acc_val: 0.385
# iteration: 306 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.38224489795918365, acc_val: 0.384
# iteration: 307 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.3822244897959184, acc_val: 0.384
# iteration: 308 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.3820204081632653, acc_val: 0.383
# iteration: 309 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.38216326530612243, acc_val: 0.384
# iteration: 310 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.3822857142857143, acc_val: 0.384
# iteration: 311 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.38246938775510203, acc_val: 0.385
# iteration: 312 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.3826326530612245, acc_val: 0.385
# iteration: 313 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.3827755102040816, acc_val: 0.386
# iteration: 314 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.38310204081632654, acc_val: 0.387
# iteration: 315 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.38357142857142856, acc_val: 0.387
# iteration: 316 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.38393877551020406, acc_val: 0.39
# iteration: 317 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.3843061224489796, acc_val: 0.391
# iteration: 318 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.38448979591836735, acc_val: 0.392
# iteration: 319 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.38471428571428573, acc_val: 0.392
# iteration: 320 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.38479591836734695, acc_val: 0.391
# iteration: 321 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.38479591836734695, acc_val: 0.391
# iteration: 322 / 576, num_iters: 1000, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.38479591836734695, acc_val: 0.391
# ...
# acc_train: 0.39177551020408163, acc_val: 0.402
# iteration: 477 / 576, num_iters: 3000, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.3916734693877551, acc_val: 0.402
# iteration: 478 / 576, num_iters: 3000, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.3916938775510204, acc_val: 0.402
# iteration: 479 / 576, num_iters: 3000, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.39163265306122447, acc_val: 0.402
# iteration: 480 / 576, num_iters: 3000, batch_size: 200, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.3916530612244898, acc_val: 0.402
# iteration: 481 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.4137142857142857, acc_val: 0.422
# iteration: 482 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.42706122448979594, acc_val: 0.43
# iteration: 483 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.43504081632653063, acc_val: 0.435
# iteration: 484 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.44142857142857145, acc_val: 0.434
# iteration: 485 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.44387755102040816, acc_val: 0.432
# iteration: 486 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.44681632653061226, acc_val: 0.429
# iteration: 487 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.44855102040816325, acc_val: 0.431
# iteration: 488 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.4499183673469388, acc_val: 0.431
# iteration: 489 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.4503061224489796, acc_val: 0.431
# iteration: 490 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.4496938775510204, acc_val: 0.428
# iteration: 491 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.4498367346938775, acc_val: 0.435
# iteration: 492 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.45026530612244897, acc_val: 0.431
# iteration: 493 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.4002857142857143, acc_val: 0.406
# iteration: 494 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.3878979591836735, acc_val: 0.393
# iteration: 495 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.3830816326530612, acc_val: 0.39
# iteration: 496 / 576, num_iters: 3000, batch_size: 500, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.3832857142857143, acc_val: 0.393
# iteration: 497 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.383530612244898, acc_val: 0.392
# iteration: 498 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.3836938775510204, acc_val: 0.394
# iteration: 499 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.3843877551020408, acc_val: 0.392
# iteration: 500 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.3850204081632653, acc_val: 0.392
# iteration: 501 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.38548979591836735, acc_val: 0.395
# iteration: 502 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.3863265306122449, acc_val: 0.396
# iteration: 503 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.3870408163265306, acc_val: 0.398
# iteration: 504 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.3873673469387755, acc_val: 0.399
# iteration: 505 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.3880612244897959, acc_val: 0.398
# iteration: 506 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.38881632653061227, acc_val: 0.398
# iteration: 507 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.38946938775510204, acc_val: 0.398
# iteration: 508 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.3902244897959184, acc_val: 0.398
# iteration: 509 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.3904489795918367, acc_val: 0.401
# iteration: 510 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.3905102040816327, acc_val: 0.401
# iteration: 511 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.3902040816326531, acc_val: 0.4
# iteration: 512 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.3899183673469388, acc_val: 0.4
# iteration: 513 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.3899183673469388, acc_val: 0.4
# iteration: 514 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.3899183673469388, acc_val: 0.4
# iteration: 515 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 100
# acc_train: 0.3899183673469388, acc_val: 0.4
# iteration: 516 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 0, hidden_size: 500
# acc_train: 0.3899183673469388, acc_val: 0.4
# iteration: 517 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 0.5, hidden_size: 10
# acc_train: 0.3898979591836735, acc_val: 0.4
# iteration: 518 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 0.5, hidden_size: 50
# acc_train: 0.3898979591836735, acc_val: 0.4
# iteration: 519 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 0.5, hidden_size: 100
# acc_train: 0.3898979591836735, acc_val: 0.4
# iteration: 520 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 0.5, hidden_size: 500
# acc_train: 0.3898979591836735, acc_val: 0.4
# iteration: 521 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 1, hidden_size: 10
# acc_train: 0.38987755102040816, acc_val: 0.4
# iteration: 522 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 1, hidden_size: 50
# acc_train: 0.38985714285714285, acc_val: 0.4
# iteration: 523 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 1, hidden_size: 100
# acc_train: 0.38983673469387753, acc_val: 0.4
# iteration: 524 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 1, hidden_size: 500
# acc_train: 0.38985714285714285, acc_val: 0.4
# iteration: 525 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.38987755102040816, acc_val: 0.4
# iteration: 526 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.38987755102040816, acc_val: 0.4
# iteration: 527 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.3898979591836735, acc_val: 0.4
# iteration: 528 / 576, num_iters: 3000, batch_size: 500, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.3899183673469388, acc_val: 0.4
# iteration: 529 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 0, hidden_size: 10
# acc_train: 0.40751020408163263, acc_val: 0.41
# iteration: 530 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 0, hidden_size: 50
# acc_train: 0.41689795918367345, acc_val: 0.425
# iteration: 531 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 0, hidden_size: 100
# acc_train: 0.42457142857142854, acc_val: 0.434
# iteration: 532 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 0, hidden_size: 500
# acc_train: 0.4306530612244898, acc_val: 0.432
# iteration: 533 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 0.5, hidden_size: 10
# acc_train: 0.43387755102040815, acc_val: 0.428
# iteration: 534 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 0.5, hidden_size: 50
# acc_train: 0.43765306122448977, acc_val: 0.43
# iteration: 535 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 0.5, hidden_size: 100
# acc_train: 0.4400816326530612, acc_val: 0.429
# iteration: 536 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 0.5, hidden_size: 500
# acc_train: 0.44224489795918365, acc_val: 0.431
# iteration: 537 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 1, hidden_size: 10
# acc_train: 0.4432244897959184, acc_val: 0.43
# iteration: 538 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 1, hidden_size: 50
# acc_train: 0.44287755102040816, acc_val: 0.43
# iteration: 539 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 1, hidden_size: 100
# acc_train: 0.4433061224489796, acc_val: 0.428
# iteration: 540 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 1, hidden_size: 500
# acc_train: 0.4448979591836735, acc_val: 0.426
# iteration: 541 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 10, hidden_size: 10
# acc_train: 0.4111020408163265, acc_val: 0.408
# iteration: 542 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 10, hidden_size: 50
# acc_train: 0.39493877551020407, acc_val: 0.4
# iteration: 543 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 10, hidden_size: 100
# acc_train: 0.3882857142857143, acc_val: 0.396
# iteration: 544 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 0.0001, reg: 10, hidden_size: 500
# acc_train: 0.38510204081632654, acc_val: 0.391
# iteration: 545 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 0, hidden_size: 10
# acc_train: 0.38516326530612244, acc_val: 0.391
# iteration: 546 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 0, hidden_size: 50
# acc_train: 0.3852857142857143, acc_val: 0.391
# iteration: 547 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 0, hidden_size: 100
# acc_train: 0.38555102040816325, acc_val: 0.391
# iteration: 548 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 0, hidden_size: 500
# acc_train: 0.3858979591836735, acc_val: 0.392
# iteration: 549 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 0.5, hidden_size: 10
# acc_train: 0.3862244897959184, acc_val: 0.392
# iteration: 550 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 0.5, hidden_size: 50
# acc_train: 0.38646938775510203, acc_val: 0.394
# iteration: 551 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 0.5, hidden_size: 100
# acc_train: 0.387, acc_val: 0.393
# iteration: 552 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 0.5, hidden_size: 500
# acc_train: 0.38748979591836735, acc_val: 0.394
# iteration: 553 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 1, hidden_size: 10
# acc_train: 0.3879183673469388, acc_val: 0.394
# iteration: 554 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 1, hidden_size: 50
# acc_train: 0.3883673469387755, acc_val: 0.394
# iteration: 555 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 1, hidden_size: 100
# acc_train: 0.38848979591836735, acc_val: 0.394
# iteration: 556 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 1, hidden_size: 500
# acc_train: 0.38848979591836735, acc_val: 0.396
# iteration: 557 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 10, hidden_size: 10
# acc_train: 0.38885714285714285, acc_val: 0.397
# iteration: 558 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 10, hidden_size: 50
# acc_train: 0.3892040816326531, acc_val: 0.4
# iteration: 559 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 10, hidden_size: 100
# acc_train: 0.38963265306122447, acc_val: 0.401
# iteration: 560 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-06, reg: 10, hidden_size: 500
# acc_train: 0.389734693877551, acc_val: 0.401
# iteration: 561 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 0, hidden_size: 10
# acc_train: 0.389734693877551, acc_val: 0.401
# iteration: 562 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 0, hidden_size: 50
# acc_train: 0.389734693877551, acc_val: 0.401
# iteration: 563 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 0, hidden_size: 100
# acc_train: 0.38971428571428574, acc_val: 0.401
# iteration: 564 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 0, hidden_size: 500
# acc_train: 0.38971428571428574, acc_val: 0.401
# iteration: 565 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 0.5, hidden_size: 10
# acc_train: 0.38971428571428574, acc_val: 0.401
# iteration: 566 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 0.5, hidden_size: 50
# acc_train: 0.3896938775510204, acc_val: 0.401
# iteration: 567 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 0.5, hidden_size: 100
# acc_train: 0.3896734693877551, acc_val: 0.401
# iteration: 568 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 0.5, hidden_size: 500
# acc_train: 0.3896734693877551, acc_val: 0.401
# iteration: 569 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 1, hidden_size: 10
# acc_train: 0.3896734693877551, acc_val: 0.401
# iteration: 570 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 1, hidden_size: 50
# acc_train: 0.3896530612244898, acc_val: 0.401
# iteration: 571 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 1, hidden_size: 100
# acc_train: 0.3896530612244898, acc_val: 0.401
# iteration: 572 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 1, hidden_size: 500
# acc_train: 0.3896530612244898, acc_val: 0.401
# iteration: 573 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 10, hidden_size: 10
# acc_train: 0.3896938775510204, acc_val: 0.401
# iteration: 574 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 10, hidden_size: 50
# acc_train: 0.3896938775510204, acc_val: 0.401
# iteration: 575 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 10, hidden_size: 100
# acc_train: 0.3896938775510204, acc_val: 0.401
# iteration: 576 / 576, num_iters: 3000, batch_size: 1000, learning_rate: 1e-08, reg: 10, hidden_size: 500
# acc_train: 0.3896938775510204, acc_val: 0.401
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-32f8d24f2582> in <module>()
#       6 param_grid = list(product(num_iters, batch_sizes, learning_rates, regularization_strengths, hidden_sizes))
#       7 net_base = TwoLayerNet(input_size=input_size, output_size=num_classes)
# ----> 8 net_best, results = tune_classifier(X_train, y_train, X_val, y_val, net_base, param_grid)
#
# <ipython-input-31-87917bc4913b> in tune_classifier(X_train, y_train, X_val, y_val, clf_class, param_grid)
#      25             clf_best = clf
#      26
# ---> 27     for lr, reg in sorted(results):
#      28         train_accuracy, val_accuracy = results[(lr, reg)]
#      29         print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
#
# ValueError: too many values to unpack (expected 2)

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# Your code
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# *Your answer*:
#
# *Your explanation:*
